# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Load data
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Normalize
X_train = X_train / 255.0
X_test = X_test / 255.0

# Flatten
X_train = X_train.reshape(-1, 784)
X_test = X_test.reshape(-1, 784)

# Model
model = Sequential([
    Dense(128, activation='relu', input_shape=(784,)),
    Dense(10, activation='softmax')
])

# Compile
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Train
model.fit(X_train, y_train, epochs=10, validation_split=0.1)

# Evaluate
model.evaluate(X_test, y_test)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# C:\Users\HP\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9232 - loss: 0.2696 - val_accuracy: 0.9685 - val_loss: 0.1182
# Epoch 2/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9644 - loss: 0.1194 - val_accuracy: 0.9740 - val_loss: 0.0938
# Epoch 3/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9760 - loss: 0.0802 - val_accuracy: 0.9732 - val_loss: 0.0831
# Epoch 4/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9823 - loss: 0.0606 - val_accuracy: 0.9778 - val_loss: 0.0747
# Epoch 5/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9857 - loss: 0.0460 - val_accuracy: 0.9770 - val_loss: 0.0773
# Epoch 6/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9886 - loss: 0.0368 - val_accuracy: 0.9797 - val_loss: 0.0731
# Epoch 7/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.9914 - loss: 0.0283 - val_accuracy: 0.9752 - val_loss: 0.0907
# Epoch 8/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9926 - loss: 0.0239 - val_accuracy: 0.9805 - val_loss: 0.0706
# Epoch 9/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9941 - loss: 0.0196 - val_accuracy: 0.9797 - val_loss: 0.0719
# Epoch 10/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.9958 - loss: 0.0153 - val_accuracy: 0.9805 - val_loss: 0.0847
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9775 - loss: 0.0811
# [0.08113683015108109, 0.9775000214576721]

# %%
# ----------------------------------------
# Task 1 — Build a Neural Network on MNIST
# ----------------------------------------

# Step 1 — Import required libraries
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Step 2 — Load MNIST dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()

print("Training data shape:", X_train.shape)
print("Testing data shape:", X_test.shape)

# Step 3 — Preprocess the data

# Normalize pixel values (0–255 → 0–1)
X_train = X_train / 255.0
X_test = X_test / 255.0

# Flatten images (28×28 → 784)
X_train = X_train.reshape(X_train.shape[0], 28 * 28)
X_test = X_test.reshape(X_test.shape[0], 28 * 28)

print("Flattened training shape:", X_train.shape)
print("Flattened testing shape:", X_test.shape)

# Step 4 — Build the Neural Network model
model = Sequential([
    Dense(128, activation='relu', input_shape=(784,)),
    Dense(10, activation='softmax')
])

# Step 5 — Compile the model
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Show model architecture
model.summary()

# Step 6 — Train the model
model.fit(
    X_train,
    y_train,
    epochs=10,
    validation_split=0.1
)

# Step 7 — Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test, y_test)

print("\nTest Accuracy:", test_accuracy)
# Out:
# Training data shape: (60000, 28, 28)
# Testing data shape: (10000, 28, 28)
# Flattened training shape: (60000, 784)
# Flattened testing shape: (10000, 784)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                      │ (None, 128)                 │         100,480 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 101,770 (397.54 KB)
#  Trainable params: 101,770 (397.54 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9220 - loss: 0.2745 - val_accuracy: 0.9650 - val_loss: 0.1253
# Epoch 2/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9639 - loss: 0.1230 - val_accuracy: 0.9722 - val_loss: 0.0964
# Epoch 3/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9745 - loss: 0.0848 - val_accuracy: 0.9747 - val_loss: 0.0861
# Epoch 4/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.9809 - loss: 0.0620 - val_accuracy: 0.9743 - val_loss: 0.0834
# Epoch 5/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9850 - loss: 0.0492 - val_accuracy: 0.9782 - val_loss: 0.0751
# Epoch 6/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9881 - loss: 0.0391 - val_accuracy: 0.9795 - val_loss: 0.0718
# Epoch 7/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9910 - loss: 0.0293 - val_accuracy: 0.9793 - val_loss: 0.0766
# Epoch 8/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9926 - loss: 0.0247 - val_accuracy: 0.9802 - val_loss: 0.0813
# Epoch 9/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9943 - loss: 0.0193 - val_accuracy: 0.9755 - val_loss: 0.0917
# Epoch 10/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - accuracy: 0.9947 - loss: 0.0168 - val_accuracy: 0.9782 - val_loss: 0.0901
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9759 - loss: 0.0878
#
# Test Accuracy: 0.9758999943733215

# %%
# ==========================================
# STEP 7: LOAD HANDWRITTEN DIGIT (PIL)
# ==========================================
# Option 1: Use a different path where your image actually exists
image_path = "path/to/your/digit.png"  # Replace with the actual path to your image file

# Option 2: Or use a test image from the MNIST dataset instead
# Comment out the Image.open code and use this alternative approach
img = X_test[0]  # Take the first test image from MNIST
img = img.reshape(28, 28)  # Reshape it back to 2D for display

# The rest of the code remains the same
img_flat = img.reshape(1, 784)


# =========================
# STEP 8: SHOW IMAGE
# =========================
plt.imshow(img, cmap="gray")
plt.title("Input Digit")
plt.axis("off")
plt.show()


# =========================
# STEP 9: PREDICT
# =========================
prediction = model.predict(img_flat)
print("Predicted Digit:", np.argmax(prediction))
print("Probabilities:", prediction)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# Predicted Digit: 7
# Probabilities: [[6.3189228e-12 6.0367710e-13 8.7427674e-09 8.2493725e-06 7.8199458e-16
#   5.1347621e-11 1.7632330e-16 9.9999177e-01 8.2010008e-09 4.5863620e-09]]

# %%
import math

# -------------------------
# Step 1: Initialize
# -------------------------
w1 = 0.5
w2 = -0.3
bias = 0.1
learning_rate = 0.1

# Input & target
x1 = 1.0
x2 = 2.0
y = 1.0   # expected output


# -------------------------
# Step 2: Weighted sum
# -------------------------
z = w1 * x1 + w2 * x2 + bias


# -------------------------
# Step 3: Sigmoid
# -------------------------
y_pred = 1 / (1 + math.exp(-z))


# -------------------------
# Step 4: Loss (MSE)
# -------------------------
loss = (y - y_pred) ** 2


# -------------------------
# Step 5: Backpropagation
# -------------------------
d_loss_d_ypred = -2 * (y - y_pred)
d_ypred_d_z = y_pred * (1 - y_pred)

d_z_d_w1 = x1
d_z_d_w2 = x2
d_z_d_b = 1

# Gradients
grad_w1 = d_loss_d_ypred * d_ypred_d_z * d_z_d_w1
grad_w2 = d_loss_d_ypred * d_ypred_d_z * d_z_d_w2
grad_b = d_loss_d_ypred * d_ypred_d_z * d_z_d_b

# Update weights
w1 -= learning_rate * grad_w1
w2 -= learning_rate * grad_w2
bias -= learning_rate * grad_b


# -------------------------
# Output
# -------------------------
print("Prediction:", y_pred)
print("Loss:", loss)
print("Updated w1:", w1)
print("Updated w2:", w2)
print("Updated bias:", bias)
# Out:
# Prediction: 0.5
# Loss: 0.25
# Updated w1: 0.525
# Updated w2: -0.25
# Updated bias: 0.125

# %%
# ============================================
# PRACTICE EXERCISE 8 — MODEL FAILURE ANALYSIS
# ============================================

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical

# --------------------------------------------
# Step 1 — Load MNIST data
# --------------------------------------------
(X_train, y_train), (X_test, y_test) = mnist.load_data()

X_train = X_train / 255.0
X_test = X_test / 255.0

y_train_cat = to_categorical(y_train)
y_test_cat = to_categorical(y_test)

# --------------------------------------------
# Step 2 — Build & train model
# --------------------------------------------
model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation="relu"),
    Dense(64, activation="relu"),
    Dense(10, activation="softmax")
])

model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

model.fit(X_train, y_train_cat, epochs=5, batch_size=32, verbose=1)

# --------------------------------------------
# Step 3 — Predict on test data
# --------------------------------------------
predictions = model.predict(X_test)
predicted_labels = np.argmax(predictions, axis=1)

# --------------------------------------------
# Step 4 — Find misclassified digits
# --------------------------------------------
misclassified_idx = np.where(predicted_labels != y_test)[0]

print("Total test samples:", len(X_test))
print("Misclassified samples:", len(misclassified_idx))

# --------------------------------------------
# Step 5 — Display some misclassified digits
# --------------------------------------------
plt.figure(figsize=(10, 5))

for i, idx in enumerate(misclassified_idx[:8]):
    plt.subplot(2, 4, i + 1)
    plt.imshow(X_test[idx], cmap="gray")
    plt.title(f"True: {y_test[idx]} | Pred: {predicted_labels[idx]}")
    plt.axis("off")

plt.suptitle("Misclassified Digits (Wrong Predictions)")
plt.show()
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 23s 7ms/step - accuracy: 0.9294 - loss: 0.2412
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - accuracy: 0.9686 - loss: 0.1033
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - accuracy: 0.9772 - loss: 0.0726
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - accuracy: 0.9826 - loss: 0.0538
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - accuracy: 0.9867 - loss: 0.0418
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step
# Total test samples: 10000
# Misclassified samples: 298

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Load data
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Preprocess
X_train = X_train.reshape(-1, 784) / 255.0
X_test = X_test.reshape(-1, 784) / 255.0

# Model
model = Sequential([
    Dense(128, activation='relu', input_shape=(784,)),
    Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=5)
model.evaluate(X_test, y_test)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 16s 7ms/step - accuracy: 0.9248 - loss: 0.2622
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - accuracy: 0.9650 - loss: 0.1170
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.9763 - loss: 0.0793
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.9813 - loss: 0.0606
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.9855 - loss: 0.0468
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9758 - loss: 0.0772
# [0.07723452150821686, 0.9757999777793884]

# %%
import numpy as np
from sklearn.neural_network import MLPClassifier

# Dummy facial features: [eye_distance, nose_length, face_width]
X = np.array([
    [5.1, 3.2, 12.0],
    [6.0, 3.8, 13.2],
    [4.9, 3.0, 11.5],
    [6.2, 4.0, 13.8]
])

# Person IDs
y = [0, 1, 0, 1]

model = MLPClassifier(hidden_layer_sizes=(10,), max_iter=1000)
model.fit(X, y)

print("Predicted Person:", model.predict([[5.8, 3.6, 13.0]]))
# Out:
# Predicted Person: [1]

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.neural_network import MLPClassifier

commands = [
    "play music",
    "open youtube",
    "turn on light",
    "turn off fan"
]

labels = ["music", "app", "device_on", "device_off"]

vectorizer = CountVectorizer()
X = vectorizer.fit_transform(commands)

model = MLPClassifier(hidden_layer_sizes=(10,), max_iter=1000)
model.fit(X, labels)

test_cmd = vectorizer.transform(["play song"])
print("Predicted Command:", model.predict(test_cmd))
# Out:
# Predicted Command: ['music']

# %%
# ============================================
# MINI PROJECT — DIGIT CLASSIFIER
# ============================================

# Step 1 — Import libraries
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical
from PIL import Image
import os

# ============================================
# Step 2 — Load MNIST dataset
# ============================================

(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Normalize pixel values
X_train = X_train / 255.0
X_test = X_test / 255.0

# One-hot encode labels
y_train_cat = to_categorical(y_train)
y_test_cat = to_categorical(y_test)

print("Training samples:", X_train.shape)
print("Testing samples:", X_test.shape)

# ============================================
# Step 3 — Build Neural Network
# ============================================

model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation="relu"),
    Dense(64, activation="relu"),
    Dense(10, activation="softmax")
])

model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

model.summary()

# ============================================
# Step 4 — Train the model
# ============================================

history = model.fit(
    X_train,
    y_train_cat,
    epochs=10,          # 🔧 Tune epochs
    batch_size=32,
    validation_split=0.2,
    verbose=1
)

# ============================================
# Step 5 — Evaluate the model
# ============================================

test_loss, test_acc = model.evaluate(X_test, y_test_cat)
print(f"\nTest Accuracy: {test_acc * 100:.2f}%")

# ============================================
# Step 6 — Tune Parameters (Experiment)
# ============================================

print("\nTry tuning:")
print("- Neurons: 64, 128, 256")
print("- Epochs: 5, 10, 20")
print("- Activation: relu / tanh")

# ============================================
# Step 7 — Test with Custom Handwritten Digit
# ============================================

print("\nCurrent folder:", os.getcwd())
print("Files:", os.listdir())

IMAGE_PATH = "digit.png"

img = Image.open(IMAGE_PATH).convert("L")
img = img.resize((28, 28))

img_array = np.array(img)

# Fix background issues
if img_array.mean() > 127:
    img_array = 255 - img_array

# Normalize
img_array = img_array / 255.0
img_array = img_array.reshape(1, 28, 28)

# Show input image
plt.imshow(img_array[0], cmap="gray")
plt.title("Custom Input Digit")
plt.axis("off")
plt.show()

# Predict
prediction = model.predict(img_array)
predicted_digit = np.argmax(prediction)

print("🤖 Predicted Digit:", predicted_digit)
print("Prediction Probabilities:", np.round(prediction[0], 3))
# Out:
# Training samples: (60000, 28, 28)
# Testing samples: (10000, 28, 28)
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten_2 (Flatten)                  │ (None, 784)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_18 (Dense)                     │ (None, 128)                 │         100,480 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_19 (Dense)                     │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_20 (Dense)                     │ (None, 10)                  │             650 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 109,386 (427.29 KB)
#  Trainable params: 109,386 (427.29 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 19s 10ms/step - accuracy: 0.9231 - loss: 0.2656 - val_accuracy: 0.9574 - val_loss: 0.1480
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 13s 9ms/step - accuracy: 0.9672 - loss: 0.1098 - val_accuracy: 0.9662 - val_loss: 0.1127
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 21s 9ms/step - accuracy: 0.9771 - loss: 0.0756 - val_accuracy: 0.9732 - val_loss: 0.0913
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.9823 - loss: 0.0567 - val_accuracy: 0.9684 - val_loss: 0.1049
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 13s 9ms/step - accuracy: 0.9863 - loss: 0.0428 - val_accuracy: 0.9743 - val_loss: 0.0921
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - accuracy: 0.9881 - loss: 0.0363 - val_accuracy: 0.9747 - val_loss: 0.1012
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 21s 9ms/step - accuracy: 0.9899 - loss: 0.0294 - val_accuracy: 0.9759 - val_loss: 0.0958
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.9923 - loss: 0.0235 - val_accuracy: 0.9750 - val_loss: 0.1019
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.9924 - loss: 0.0221 - val_accuracy: 0.9753 - val_loss: 0.1038
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - accuracy: 0.9939 - loss: 0.0181 - val_accuracy: 0.9722 - val_loss: 0.1178
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9710 - loss: 0.1220
#
# Test Accuracy: 97.10%
#
# Try tuning:
# - Neurons: 64, 128, 256
# - Epochs: 5, 10, 20
# - Activation: relu / tanh
#
# Current folder: C:\Users\HP
# Files: ['-1.14-windows.xml', '.anaconda', '.android', '.cache', '.conda', '.condarc', '.continuum', '.dbus-keyrings', '.idlerc', '.ipynb_checkpoints', '.ipython', '.jupyter', '.keras', '.matplotlib', '.ms-ad', '.nuget', '.vscode', '3D Objects', 'anaconda3', 'anaconda_projects', 'AppData', 'Application Data', 'archive.zip', 'Bank Customer Segmentation.csv', 'bank_transactions_data_2.csv', 'ChatGPT Full Data.csv', 'Contacts', 'Cookies', 'customer_shopping_data.csv', 'DEC12.ipynb', 'DEC13.ipynb', 'Default_Fin.csv', 'Desktop', 'digit.png', 'Documents', 'Downloads', 'E-commerce Customer Behavior - Sheet1.csv', 'Favorites', 'IntelGraphicsProfiles', 'Iris.csv', 'IRIS.ipynb', 'Links', 'Local Settings', 'Mall_Customers.csv', 'MicrosoftEdgeBackups', 'Music', 'My Documents', 'NetHood', 'New folder', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{a1f9b074-c924-11ef-842f-9d15c3b66eba}.TM.blf', 'NTUSER.DAT{a1f9b074-c924-11ef-842f-9d15c3b66eba}.TMContainer00000000000000000001.regtrans-ms', 'NTUSER.DAT{a1f9b074-c924-11ef-842f-9d15c3b66eba}.TMContainer00000000000000000002.regtrans-ms', 'ntuser.ini', 'OneDrive', 'Pictures', 'PrintHood', 'Recent', 'Saved Games', 'scikit_learn_data', 'Searches', 'SendTo', 'Start Menu', 'Templates', 'Untitled.ipynb', 'Untitled1.ipynb', 'Untitled2.ipynb', 'Videos']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step
# 🤖 Predicted Digit: 5
# Prediction Probabilities: [0.    0.    0.    0.    0.    0.745 0.    0.    0.    0.255]
